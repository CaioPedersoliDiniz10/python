# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def calcula_ticks(lista,barras):
    lista.sort()
    menor_valor = lista[0]
    maior_valor = lista[-1]
    intervalo = (maior_valor - menor_valor)/barras
    ticks = [menor_valor]
    ultimo = menor_valor+intervalo
    ticks.append(ultimo)
    for x in range(barras-1):
        ultimo += intervalo
        ticks.append(ultimo)
    return ticks

# %%
km = pd.Series([4,6,6,7,11,13,18,19,21,24,26,27,35,36,36,42,43,45,49])

# %%
def frequencia_relativa(total,yticks):
    freq_rel = []
    for item in yticks:
        x = item/total
        freq_rel.append("{0:.2f}%".format(x*100))
    return freq_rel

# %%
def gera_histograma(barras,data_series,titulo,unidade):
    lista = data_series.values
    ax = data_series.plot.hist(bins=barras,rwidth=0.95)

    yticks = ax.get_yticks()
    total = len(lista)
    freq_rel = frequencia_relativa(total,yticks)
    ax.set_yticklabels(freq_rel)
    
    fig = plt.gcf()
    fig.set_size_inches(8,4)
    fig.set_dpi(150)

    ticks = calcula_ticks(lista,barras)
    plt.xticks(ticks)
    plt.title(titulo)
    plt.xlabel(unidade)
    plt.ylabel('Frequência')
    plt.grid(axis='y')

# %%
gera_histograma(5,km,'Distância','km')
# Out:
# C:\Users\caiod\AppData\Local\Temp\ipykernel_13468\1887895931.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(freq_rel)

# %%
import pandas as pd

# %%
data = pd.read_csv('weight-height.csv')

# %%
data['Altura']= data['Height']*2.54

# %%
data['Altura']=data['Altura cm'].round(0)

# %%
data =data.drop('Altura cm', axis = 1)

# %%
# Seleciona apenas as linhas onde Gender == 'Female' e pega a coluna Altura
Altura_Mulheres = data.loc[data['Gender'] == 'Female', 'Altura']

# %%
gera_histograma(9,Altura_Mulheres,'Altura de Mulheres','cm')
# Out:
# C:\Users\caiod\AppData\Local\Temp\ipykernel_13468\1887895931.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(freq_rel)

# %%
Altura_Homens = data.loc[data['Gender']== 'Male' , 'Altura']

# %%
import statistics as stats

# %% [markdown]
# # Média
# Somatório de valores de determinados elementos dividido pela quantidade de elementos somados.

# %%
Altura_Mulheres.mean()
# Out:
# np.float64(161.8112)

# %% [markdown]
# # Mediana
# Dada uma sequência de valores ordenados em ordem crescente ou decrescente, a mediana é o valor central dessa sequência. Caso haja dois valores centrais, a mediana é dada pela média aritmética deles.

# %%
stats.median(altura_homens)
# Out:
# 175.0

# %% [markdown]
# # Moda
# Dado um conjunto de valores, a moda é o número que mais se repete.

# %%
stats.mode(altura_homens)
# Out:
# 175.0
